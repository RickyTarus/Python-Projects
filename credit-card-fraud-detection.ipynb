# %% [markdown]
# ## **Load Data**

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/credit-card-data/creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.loc[:, 'Amount'].mean()
# Out:
# 88.34961925093133

# %%
df.loc[0, 'V1':'V28'].mean()
# Out:
# 0.11006274276798754

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ### Data separation as X and Y

# %%
y = df['Amount']
y
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
X = df.drop('Amount', axis=1)
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# 0       0.462388  0.239599  0.098698  0.363787  ...  0.251412 -0.018307
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.524980  0.247998
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300
# 4       0.095921  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  1.475829  0.213454
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.059616  0.214205
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.001396  0.232045
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.127434  0.265245
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 30 columns]

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 201788  134039.0  2.023734 -0.429219 -0.691061 -0.201461 -0.162486  0.283718
# 179369  124044.0 -0.145286  0.736735  0.543226  0.892662  0.350846  0.089253
# 73138    54997.0 -3.015846 -1.920606  1.229574  0.721577  1.089918 -0.195727
# 208679  137226.0  1.851980 -1.007445 -1.499762 -0.220770 -0.568376 -1.232633
# 206534  136246.0  2.237844 -0.551513 -1.426515 -0.924369 -0.401734 -1.438232
# ...          ...       ...       ...       ...       ...       ...       ...
# 212912  139039.0 -0.711190  0.439833  0.963645 -1.558006 -0.849632  0.856514
# 65615    51670.0 -2.720797 -2.019693  0.555552 -1.214493  1.091755 -1.048706
# 253799  156425.0 -1.825901 -0.539605 -0.263009  0.516277 -0.432071  0.097944
# 210755  138109.0 -0.360815  0.942995  0.256998  0.385238  0.606772 -0.806142
# 56088    47268.0  0.631569 -0.899715  1.229477  1.833747 -1.245935  0.445119
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 201788 -0.674694  0.192230  1.124319  ... -0.171390 -0.195207 -0.477813
# 179369  0.626708 -0.049137 -0.732566  ...  0.206709 -0.124288 -0.263560
# 73138  -0.462586  0.919341 -0.612193  ...  0.842838  0.274911 -0.319550
# 208679  0.248573 -0.539483 -0.813368  ... -0.196551 -0.406722 -0.899081
# 206534 -0.119942 -0.449263 -0.717258  ... -0.045417  0.050447  0.125601
# ...          ...       ...       ...  ...       ...       ...       ...
# 212912 -2.359232 -4.103076 -1.221692  ...  0.467513  0.526395  0.555138
# 65615  -0.732389  0.670327 -1.697393  ... -0.532981 -0.510275 -1.524682
# 227811 -0.032865  0.526284  0.308714  ... -0.081972  0.253895  0.810952
# 30905  -0.559136 -0.112942 -2.424942  ... -0.214777 -0.365323 -0.924197
# 104456  0.545958  0.005842 -0.510117  ...  0.055858 -0.225225 -0.591498
# 86539   1.848399 -0.377848  0.027687  ...  2.304400  0.743910 -0.554065
#
#              V23       V24       V25       V26       V27       V28  Class
# 49089  -0.130270  1.025935  0.847990 -0.271476  0.060052  0.018104      0
# 154704  0.087188  0.570679  0.101899  0.620842 -0.048958 -0.042831      0
# 67247  -0.128376  0.286638 -0.136700  0.913904 -0.083364  0.052485      0
# 251657  0.223474 -1.075605 -0.188519  0.267672 -0.071733 -0.072238      0
# 201903  0.381606  0.332001 -0.334757  0.448890  0.168585  0.004955      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 232852  0.205004 -0.427723 -0.435864 -0.675525  0.006642 -0.020707      0
# 227811 -0.234653  0.094260 -0.073665  0.633309  0.212842  0.123439      0
# 30905   0.124201  0.171056  0.168267 -0.458243 -0.002141  0.018252      0
# 104456  0.189725 -0.046576 -0.094671  0.058969 -0.008845  0.100746      0
# 86539  -1.214423  0.131784  0.277150 -0.362074 -0.216895  0.227171      0
#
# [56962 rows x 30 columns]

# %%
y_train
# Out:
# 201788      0.77
# 179369     36.14
# 73138     179.95
# 208679    181.06
# 206534      8.20
#            ...
# 212912     49.90
# 65615      34.34
# 253799    639.40
# 210755      1.99
# 56088     235.00
# Name: Amount, Length: 227845, dtype: float64

# %%
y_test
# Out:
# 49089        1.99
# 154704       6.99
# 67247      306.16
# 251657       0.99
# 201903      30.27
#            ...
# 232852     139.90
# 227811      11.35
# 30905       99.37
# 104456       1.29
# 86539     1259.00
# Name: Amount, Length: 56962, dtype: float64

# %% [markdown]
# ## **Model Building**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# **Training the model**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Applying the model to make a prediction**

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)
print(y_lr_train_pred)
# Out:
# [  8.79804361  52.68282278 271.9841854  ... 678.46456583 -11.2300453
#  225.11562913]

# %%
print(y_lr_test_pred)
# Out:
# [1.44816402e+01 1.57609795e+01 2.90499921e+02 ... 9.99439982e+01
#  3.44258220e-01 1.13589592e+03]

# %% [markdown]
# **Evaluate the model**

# %%
y_train
# Out:
# 201788      0.77
# 179369     36.14
# 73138     179.95
# 208679    181.06
# 206534      8.20
#            ...
# 212912     49.90
# 65615      34.34
# 253799    639.40
# 210755      1.99
# 56088     235.00
# Name: Amount, Length: 227845, dtype: float64

# %%
print(y_lr_train_pred)
# Out:
# [  8.79804361  52.68282278 271.9841854  ... 678.46456583 -11.2300453
#  225.11562913]

# %% [markdown]
# **Evaluate model performance[](http://)**

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ', lr_train_mse)
print('LR R2 (Train): ', lr_train_r2)
print('LR MSE (Test): ', lr_test_mse)
print('LR R2 (Test): ', lr_test_r2)
# Out:
# LR MSE (Train):  5158.288491318138
# LR R2 (Train):  0.9205253935313903
# LR MSE (Test):  5233.922358812315
# LR R2 (Test):  0.9015753965852097

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ('Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2')
lr_results
# Out:
#               Method Training MSE Training R2     Test MSE   Test R2
# 0  Linear Regression  5158.288491    0.920525  5233.922359  0.901575

# %% [markdown]
# ## **Random Forest**

# %% [markdown]
# **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# **Applying the model to make a prediction**

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method  Training MSE Training R2     Test MSE   Test R2
# 0  Random Forest  27626.580692    0.574353  23577.01493  0.556631

# %% [markdown]
# ## **Model Comparison**

# %%
df_models = pd.concat([lr_results, rf_results], axis=0)
df_models.reset_index(drop=True)
# Out:
#               Method  Training MSE Training R2     Test MSE   Test R2
# 0  Linear Regression   5158.288491    0.920525  5233.922359  0.901575
# 1      Random Forest  27626.580692    0.574353  23577.01493  0.556631

# %% [markdown]
# # **Data Visualization of prediction results**

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(x=y_train, y=y_lr_train_pred, c='#7CAE00', alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.ylabel('Predict Class')
plt.xlabel('Experimental Class')
plt.plot(y_train, p(y_train), '#f8766D')

# %% [markdown]
# The scatterplot shows a positive correlation
